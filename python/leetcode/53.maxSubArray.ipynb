# %%
# 问题转换成：求解前缀和数组两个元素之差的最大值

from itertools import accumulate
def maxSubArray(nums: list[int]) -> int:
    pre_sum = list(accumulate(nums, initial=0))
    ptr = 0
    min_val = pre_sum[ptr]
    n = len(pre_sum)
    ans = pre_sum[1]
    while ptr < n-1:
        while pre_sum[ptr+1] > pre_sum[ptr] and ptr < n-1:
            ptr+=1
        ans = max(nums[ptr] - min_val, ans)
        ptr += 1
        min_val = nums[ptr]
    return ans

# %%
nums = [-2,1,-3,4,-1,2,1,-5,4]
maxSubArray(nums)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 nums = [-2,1,-3,4,-1,2,1,-5,4]
# ----> 2 maxSubArray(nums)
#
# Cell In[1], line 11, in maxSubArray(nums)
#       9 ans = pre_sum[1]
#      10 while ptr < n-1:
# ---> 11     while pre_sum[ptr+1] > pre_sum[ptr] and ptr < n-1:
#      12         ptr+=1
#      13     ans = max(nums[ptr] - min_val, ans)
#
# IndexError: list index out of range
