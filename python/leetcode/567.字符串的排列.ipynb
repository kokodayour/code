# %%
from collections import Counter
def checkInclusion(s1: str, s2: str) -> bool:
    return True if Counter(s2) > Counter(s1) else False

# %%
s1 = "ab" 
s2 = "eidbaooo"
checkInclusion(s1, s2)
# Out:
# True
