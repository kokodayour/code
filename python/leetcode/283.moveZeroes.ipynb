# %%
# 参考快速排序 确定一个待分割的点作为基准值
# 通过基准值将数组分为两部分，左边是小于等于基准值的元素，右边是大于基准值的元素
def moveZeroes(nums: list[int]) -> None:
    """
    Do not return anything, modify nums in-place instead.
    """
    n = len(nums)
    left = right = 0
    while right < n:
        if nums[right] != 0:
            nums[left], nums[right] = nums[right], nums[left]
            left += 1
        right += 1

# %%
def moveZeroes(nums: list[int]) -> None:
    """
    Do not return anything, modify nums in-place instead.
    """
    for i in range(len(nums)):
        # determine whether the previous element is 0
        # use while for i don't know how many zero in front of nums[i]
        while nums[i] !=0:
            if i-1 > -1 and nums[i-1] == 0:
                nums[i], nums[i-1] = nums[i-1], nums[i]
                i -= 1
            else:
                break
    return nums

# %%
def moveZeroes(nums):
    nonZeroIndex = 0
    for i in range(len(nums)):
        if nums[i] != 0:
            # swap nonZeroElems to where they should be 
            nums[i], nums[nonZeroIndex] = nums[nonZeroIndex], nums[i]
            nonZeroIndex += 1

# %%
nums = [0,1,0,3,12]
moveZeroes(nums)
