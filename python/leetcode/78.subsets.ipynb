# %%
def subsets(nums: list[int]) -> list[list[int]]:
    n = len(nums)
    ans = []
    # 0: not selected and 1: selected
    # path = [0]*n
    def dfs(x, s):
        for i in range(n):
            
    dfs(0, set(nums))
    return ans
