# %%
from node import *
def oddEvenList(head):
    i = 1
    cur = head
    dummy = odd = even = ListNode()
    while cur:
        if i%2:
            odd.next = cur
            odd = odd.next
        else:
            even.next = cur
            even = even.next
        i += 1
        cur = cur.next
    # 如果节点个数是奇数的话 even的next是奇数 如2->4->5
    # 不知道为什么是超出内存限制的错误 明明没写死循环
    even.next = None
    odd.next = dummy.next
    return head

# %%
def oddEvenList(head):
    if not head:
        return head
    
    evenHead = head.next
    odd, even = head, evenHead
    while even and even.next:
        odd.next = even.next
        odd = odd.next
        even.next = odd.next
        even = even.next
    odd.next = evenHead
