# %%
def longestPath(parent, s):
    # 输入节点 返回以该节点为头节点的路径数组
    # 最长路径可能是以该节点为头节点(数组存) 以该节点为转折节点(实时更新)
    def dfs(node) -> list[list[int]]:
        if node is None:
            return
        # 遍历所有的子节点(优化)
        res = [] # 所有的子路径
        for i, x in enumerate(parent):
            if i == node:
                res.append(dfs(x))

# %%
parent = [-1,0,0,1,1,2]
s = "abacbe"
parent = [-1,0,0,0]
s = "aabc"
longestPath(parent, s)
# Out:
# 2
